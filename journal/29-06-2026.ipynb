# %% [markdown]
# # 1. Qu'est-ce que j'ai produit hier ? (TP terminé, exercice, morceau de projet, même partiel)

# %% [markdown]
# ####

# %% [markdown]
# au début j'ai clouné le dossier corrige0 et ajouté mon travail dedans (1er api open data soft).
# donc, j'ai trouvé l'api des festivals en france et j'ai créé une fichier marie.py pour récuperer les données d'api et afficher les 5 premiers fastivals , et j'ai ajouter la création du tableau festivals dans le fichier schema et le présenter.

# %% [markdown]
# # 2\. Où est-ce que j'ai bloqué, et comment je m'en suis sorti ? (relecture du cours, corrigé, camarade, formateur, IA : dites lequel, c'est une information utile, pas un aveu)

# %% [markdown]
# au début j'était bloqué sur trouver l'api de listes des banques en France, c'était restricté l'accès à cette api, donc j'ai changé de stratégie et j'ai décidé de trouvé d'autre api , donc j'ai trouvé une api de listes des festivals en france, cette api est plus accessible et elle fournit des informations sur les festivals, y compris codes insee, les lieux et les types de festivals. J'ai commencé à explorer cette api et à récupérer des données pour les intégrer dans mon projet.

# %% [markdown]
# # 3\. Qu'est-ce que je referais autrement si je recommençais ?

# %% [markdown]
# Je vais trouver n'import quelle api qui contient code insee.pour n'est pas être bloqué.

# %% [markdown]
# # 4\. Qu'est-ce qui reste flou ? (une question précise, pas « tout »)

# %%
aujourd'hui j'ai compris plus sur cette projet. pas de question jusqu'à présent. c'était très important pour travaillet individuellement pour savoir toutes les détails du projet. Je vais continuer à travailler dessus et je vous tiendrai informé si j'ai des questions ou des préoccupations.
