# %% [markdown]
# # 1. Qu'est-ce que j'ai produit hier ? (TP terminé, exercice, morceau de projet, même partiel)

# %% [markdown]
# ####

# %% [markdown]
# Hier, j'ai fini avec Salma le RGPD brief et préparer à le présenter aujourd'hui mais on a pas fini tous donc, on l'a continuer chez nous.
# Kim a fait un atelier pour préparer le CV et négocier le stage.
# Selim a fait un life code et répondre à ce qu'on a écrit dans les journals précédents.

# %% [markdown]
# # 2\. Où est-ce que j'ai bloqué, et comment je m'en suis sorti ? (relecture du cours, corrigé, camarade, formateur, IA : dites lequel, c'est une information utile, pas un aveu)

# %% [markdown]
# rien m'a bloqué! tous c'était claire

# %% [markdown]
# # 3\. Qu'est-ce que je referais autrement si je recommençais ?

# %% [markdown]
# lire profondement le site internet pour comprendre tous les informations légales (RGPD)

# %% [markdown]
# # 4\. Qu'est-ce qui reste flou ? (une question précise, pas « tout »)

# %% [markdown]
# rien
