# %% [markdown]
# # 1. Qu'est-ce que j'ai produit hier ? (TP terminé, exercice, morceau de projet, même partiel)

# %% [markdown]
# Hier, j'ai travaillé sur le TP 10 SQL en Python. Jai fini de lire et comprendre tous les exemples et j'ai réussi à connecté avec sqlite et avec postgres en mettant mon mot de pass , j'ai lu le tp avec salma et j'ai l'expliqué parceque je peux comprends le sql.

# %% [markdown]
# # 2\. Où est-ce que j'ai bloqué, et comment je m'en suis sorti ? (relecture du cours, corrigé, camarade, formateur, IA : dites lequel, c'est une information utile, pas un aveu)

# %% [markdown]
# J'ai particulièrement bloqué sur la parti "Insertion très efficace avec pandas : to_sql" quand a créé le tableau de pandas parceque j'ai reéxecuté! m parce que était : if_exists='fail' donc je l'ai remplacé par : "replace" , et chunksize=None , et j'avais pas compris pourquoi j'ai le resultat 1000 ! donc à cause de shunksize! et sql permet de 1000 lines max et si je met chunksize = 500 par exemple je vais recuperer toues les lines 10 000 lines.

# %% [markdown]
# # 3\. Qu'est-ce que je referais autrement si je recommençais ?

# %% [markdown]
# Je prendrais plus de temps au départ pour structurer les méthodes complexes! surtous qui sont à la fin de tp !

# %% [markdown]
# # 4\. Qu'est-ce qui reste flou ? (une question précise, pas « tout »)

# %% [markdown]
# La differance entre "to_sql" , et "read_sql"
