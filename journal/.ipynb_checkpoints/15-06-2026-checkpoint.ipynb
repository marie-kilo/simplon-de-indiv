# %% [markdown]
# # 1. Qu'est-ce que j'ai produit hier ? (TP terminé, exercice, morceau de projet, même partiel)

# %% [markdown]
# ####

# %% [markdown]
# j'ai travaillé sur les exercise (2 et 3) TP 10 SQL en Python, j'ai écouter les présentations des projets pour mes camarades, et enfin j'ai travaillé avec salma sur le brief de rgpd , on a fini la parti 1 et 2 ( on a pris le site de sezan, et la fonctionalité de system du recommendation et on a fait le erdiagram).

# %% [markdown]
# # 2\. Où est-ce que j'ai bloqué, et comment je m'en suis sorti ? (relecture du cours, corrigé, camarade, formateur, IA : dites lequel, c'est une information utile, pas un aveu)

# %% [markdown]
# j'avais bloqué sur l'exercise 2 de tp10 (comment je vais scraper les tableaux parceque j'ai pensé à le faire avec beautifulsoup mais après mes camarades m'ont conseillé de faire avec pandas comme il est écrit dans le tp10, et après  j'ai utilisé un peu l'ia pour accélerer mais j'ai tous compris.

# %% [markdown]
# # 3\. Qu'est-ce que je referais autrement si je recommençais ?

# %% [markdown]
# Je prendrais plus de temps pour relire le tp pour structurer plus les informations qui concernent créer les tableaux avec sqlite et postregres pour savoir la différances!

# %% [markdown]
# # 4\. Qu'est-ce qui reste flou ? (une question précise, pas « tout »)

# %% [markdown]
# le brief était un peu flou mais en avançant d'y travailler avec salma je le comprends mieux .
