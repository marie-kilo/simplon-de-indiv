# %% [markdown]
# # 1. Qu'est-ce que j'ai produit hier ? (TP terminé, exercice, morceau de projet, même partiel)

# %% [markdown]
# ####

# %% [markdown]
# j'ai travaillé sur le projet megabase_group_3, et git_tutorials, j'ai créé une réperatoire pour megabase_group_3 et ajouté mes camarades et créé des branches, pour collaborer avec eux une branche principale et 2 branches personnelles.et faire push notre travail et le merge ensemble.

# %% [markdown]
# # 2\. Où est-ce que j'ai bloqué, et comment je m'en suis sorti ? (relecture du cours, corrigé, camarade, formateur, IA : dites lequel, c'est une information utile, pas un aveu)

# %%
j'étais bloqué à comprendres les branches sur github mais après le prof Selim est venue pour aider chaque groupe donc ça m'a aidé à comprendre plus.
2ème chose la récupération les apis EHPAD.

# %% [markdown]
# # 3\. Qu'est-ce que je referais autrement si je recommençais ?

# %%
plus de travail en groupe pour négocier ensemble.

# %% [markdown]
# # 4\. Qu'est-ce qui reste flou ? (une question précise, pas « tout »)

# %%
pas de question.
