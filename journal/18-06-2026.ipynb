# %% [markdown]
# # 1. Qu'est-ce que j'ai produit hier ? (TP terminé, exercice, morceau de projet, même partiel)

# %% [markdown]
# ####

# %% [markdown]
# J'ai travaillé sur le brief d'insertation de donnée .J'ai fini avec Mohammed les methodes: 1 à 8 (écrire et execution) et on a fait la visualisation

# %% [markdown]
# # 2\. Où est-ce que j'ai bloqué, et comment je m'en suis sorti ? (relecture du cours, corrigé, camarade, formateur, IA : dites lequel, c'est une information utile, pas un aveu)

# %% [markdown]
# la microphone de Mohammad avait coupé et il entendait rien donc j'était bloqué sur ce qu'il a fait pour les methodes 7 et 8. mais aprés il m'a expliqué un peu.

# %% [markdown]
# # 3\. Qu'est-ce que je referais autrement si je recommençais ?

# %% [markdown]
# j'aurais écrit le code moi même, parce que Mohammed qui l'a écrit !(j'ai fait l'analyse) mais j'ai compris qu'est ce qu'il a fait, donc je l'ai bien compris.

# %% [markdown]
# # 4\. Qu'est-ce qui reste flou ? (une question précise, pas « tout »)

# %% [markdown]
# pas de question
