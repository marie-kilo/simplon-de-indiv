# %% [markdown]
# # 1. Qu'est-ce que j'ai produit hier ? (TP terminé, exercice, morceau de projet, même partiel)

# %% [markdown]
# ####

# %% [markdown]
# hier j'ai fait la presentation avec Salma sur le RGPD, et l'après midi j'ai commencé le brief d'insertation de donnée avec Mohammad, conc on 'a fait la partie de générer de données avec Faker et faker-vehicle pour générer 1000,100000,1000000 lignes de données et on a fait la connection avec postgres et creation de tableau cars qui va contenir les lignes générées, on a fait le travail en creation des classes pour chaque étape.

# %% [markdown]
# # 2\. Où est-ce que j'ai bloqué, et comment je m'en suis sorti ? (relecture du cours, corrigé, camarade, formateur, IA : dites lequel, c'est une information utile, pas un aveu)

# %% [markdown]
# j'était bloqué pour comprendre comment on va génerer les données des voitures avec Faker , après on a trouver qu'il ya une librarie pour les voiture qui génère le nom , la marque,l'anné des voitures. et on l'a utilisé avec random , mais quand on réexecute le code il génère d'autre données différens à chaque fois! donc on a trouvé 'seed()' pour conserver le même données qu'on a générer dans la mémoire.
# A la fin c'était un peu compliqué de comprendre comment Mohammad a cré les classes.j'ai trouvais il a compliqué les chose mais ça va m'aider au future.

# %% [markdown]
# # 3\. Qu'est-ce que je referais autrement si je recommençais ?

# %% [markdown]
# Je préférait de travaillé pas avec les classes,mais je pense ça sera plus facile pour les prochaines étapes.

# %% [markdown]
# # 4\. Qu'est-ce qui reste flou ? (une question précise, pas « tout »)

# %% [markdown]
# pas de question
