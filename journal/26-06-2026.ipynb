# %% [markdown]
# # 1. Qu'est-ce que j'ai produit hier ? (TP terminé, exercice, morceau de projet, même partiel)

# %% [markdown]
# ####

# %% [markdown]
# j'ai continuer la collecte de données pour les Gares et les Biblithèques. et on a continué à travaillé dans le "main" avec Touhami life code et comprendre comment le prof Selim a fait et organisé le main. j'ai fait push mon travail dans mon branch que j'ai créé hier marie/2026-06-25.

# %% [markdown]
# # 2\. Où est-ce que j'ai bloqué, et comment je m'en suis sorti ? (relecture du cours, corrigé, camarade, formateur, IA : dites lequel, c'est une information utile, pas un aveu)

# %% [markdown]
# Toujours le blocagues sur choisir la bonne API parce que une seule API ne contient pas toutes les données qu'on a besoin. donc je cherche une deusième API qui contient les données demandées et vérifié tous et fusionné les 2 resultats dans une seule tableau et affiché les résultats.
# La deusième bloquage, pour les biblithèques qu'on je fait offset et limit 100 j'ai eu d'erreur. 404 mais erreur de requet de api ! j'ai cherché c'est quoi cette erreur! parceque l'api ne nous donne pas plus que 10 000 lignes ! et les biblithèques son plus de 15 milles! j'ai essayé plusieures chois de corriger le code mais j'ai eu le même erreur! même j'ai essayé avec le code de Selim
# "if offset + limit >= 10_000:  # safety guard: the API refuse au délà de 1_000_000
#             break"
# il m'a donné que 10 000 biblithèques mais sans erreur! donc à la fin j'ai ajouté un filtrage pour les departements et j'ai réussi à récupérer toutes les biblithèques en France (15654 bibliothèques).

# %% [markdown]
# # 3\. Qu'est-ce que je referais autrement si je recommençais ?

# %% [markdown]
# Commencé par le main ! comme le prof a nous expliqué pour l'organiser et chaque membre de groupe fait une partie! en verticale

# %% [markdown]
# # 4\. Qu'est-ce qui reste flou ? (une question précise, pas « tout »)

# %% [markdown]
# pas de question précise. mais je dois comprendre plus comment organiser le 'main'. et la sync de merge dans git.
