# %% [markdown]
# # 1. Qu'est-ce que j'ai produit hier ? (TP terminé, exercice, morceau de projet, même partiel)

# %% [markdown]
# ####

# %% [markdown]
# hier j'ai corrigé la collecte de données des Mairies et continué la collecte de données de l'api Lycées et les collèges ( et fusioné 2 API's pour récupérer les codes INSEE et le nombre d'élèves) et on a fait ensemble code life pour "main".

# %% [markdown]
# # 2\. Où est-ce que j'ai bloqué, et comment je m'en suis sorti ? (relecture du cours, corrigé, camarade, formateur, IA : dites lequel, c'est une information utile, pas un aveu)

# %% [markdown]
# j'étais bloqué sur la collecte de données des Mairies et après grâce à Selim le prof qui nous a aidé et expliqué comment fait, A la fin il nous a donné le code :{"where": 'pivot LIKE "mairie"'} moi je filtrais sur pivot local que l'IA m'a donné! pour celà j'était bloqué.
# et les bloquages toujours sur l'api et sur quoi on va filtrer! comme pour les collèges. j'ai cherché bien sur l'api si il existe les collèges , donc je l'ai trouvé avec le codage de json et moi je faisais le filtrage sur COLLEGE ==> le vrai : Collège. Donc J'ai bien compris comment cherché et trouver la bonne API .

# %% [markdown]
# # 3\. Qu'est-ce que je referais autrement si je recommençais ?

# %% [markdown]
# Dès le debut il faut comprendre l'API et qu'est-ce qu'on va trouver dedans. et je prefère dès le début qu'on travail en verticale mais personnes ne comprenais comment il faut faire.. ça veut dire il fallait que chaque personne prendre un tableau et appliquer toutes les étapes; la collecte, la nettoyage, le chargement..tous et après on merge les tableaux dans la base de donnée.

# %% [markdown]
# # 4\. Qu'est-ce qui reste flou ? (une question précise, pas « tout »)

# %% [markdown]
# la syncronisation de merge pour les branches reste flou de coup j'ai fait une nouvelle branche pour aujourd'hui pour enregistrer mon travail mais sans pull just add commit push pour n'est pas le perdre.
